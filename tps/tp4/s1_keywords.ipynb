# %% [markdown]
# # Extraction de Keywords

# %% [markdown]
# ## Imports

# %%
import os
import yake

# %% [markdown]
# ## Extraire les mots clés d'un document avec Yake

# %% [markdown]
# https://github.com/LIAAD/yake

# %%
# Instantier l'extracteur de mots clés
kw_extractor = yake.KeywordExtractor(lan="fr", top=50)
kw_extractor

# %%
# Lister les Fichiers
data_path = "../data/txt/"
files = [f for f in os.listdir(data_path) if f.endswith('.txt')]

# %%
# Imprimer le nombre de fichiers identifiés
len(files)
# Out:
# 539

# %%
# Les dix premiers fichiers
files[:10]
# Out:
# ['KB_JB838_1960-07-01_01-00001.txt',
#  'KB_JB838_1960-07-01_01-00002.txt',
#  'KB_JB838_1960-07-01_01-00003.txt',
#  'KB_JB838_1960-07-01_01-00004.txt',
#  'KB_JB838_1960-07-01_01-00005.txt',
#  'KB_JB838_1960-07-01_01-00006.txt',
#  'KB_JB838_1960-07-01_01-00007.txt',
#  'KB_JB838_1960-07-01_01-00008.txt',
#  'KB_JB838_1960-07-01_01-00009.txt',
#  'KB_JB838_1960-07-01_01-00010.txt']

# %%
# Choisir un fichier
this_file = files[0]
this_file
# Out:
# 'KB_JB838_1960-07-01_01-00001.txt'

# %%
# Récupérer le texte du fichier
text = open(os.path.join(data_path, this_file), 'r', encoding='utf-8').read()
text[:500]
# Out:
# "74* ANNEE — N* 157 • JOURNAL OUOTtDlîN 24 Pages - 2 fr. Congo « h. franc» t H. T. 0 (r 30 — Sulu» t 0 tr. 40 9uUl9» CHEQUES POSTAUX PUBltCITE t CompU n* 5674 ROSSEL 4 C'» VENTE i Soir «t Soir Illustré t I46B6 Rotxl i C 1 * DONS aux CEuvr#» du Soir {,14232 Rouol 6 C'* Les manuscrits non Inséré* ne sont pas rendus ACENCC ROS6EL . Annonces et Publicité LE SOIR - Vente et Abonnements : BRUXELLES I : 112, rue Royale. 112 PARIS IS'Is 73, r. d'Anjou, T. EURopa 36.16 PLACE DE LOUVAIN. 21 - BRUXELLES I ."

# %%
# Extraire les mots clés de ce texte
keywords = kw_extractor.extract_keywords(text)
keywords
# Out:
# [('Congo', np.float64(0.0035544721420038756)),
#  ('Roi', np.float64(0.009964900188224667)),
#  ('BELGIQUE', np.float64(0.012557014597813367)),
#  ('JOURNAL OUOTtDlîN', np.float64(0.013761520781540299)),
#  ('Congo belge', np.float64(0.01655950118676602)),
#  ('roi Léopold', np.float64(0.025181965167696413)),
#  ('Kasavubu', np.float64(0.028717523516119944)),
#  ('congolais', np.float64(0.03031038904655707)),
#  ('ministre', np.float64(0.03424331922393459)),
#  ('Lumumba', np.float64(0.03446495516183307)),
#  ('Léopoldville', np.float64(0.03527806131129645)),
#  ('Congo belge enKtant', np.float64(0.037814952703583274)),
#  ('Soir', np.float64(0.03889463173828061)),
#  ('président Kasavubu', np.float64(0.03909563436178895)),
#  ("BELGIQUE DONNE L'INDÉPENDANCE", np.float64(0.041474172416267274)),
#  ('Parlement congolais Messieurs', np.float64(0.044786010725602315)),
#  ('HISTORIQUE BELGIQUE DONNE', np.float64(0.04543181012744327)),
#  ('voiture', np.float64(0.045589176709795745)),
#  ('Roi arrive', np.float64(0.05089644878300064)),
#  ('JOURNÉE HISTORIQUE BELGIQUE', np.float64(0.05327137510820748)),
#  ('belge', np.float64(0.053683707332531326)),
#  ('ministres belges', np.float64(0.05510447129381154)),
#  ('Patrice Lumumba', np.float64(0.05650433776290375)),
#  ('président', np.float64(0.05802261210102012)),
#  ('grandes', np.float64(0.05913094473301319)),
#  ('République du Congo', np.float64(0.05941511810684503)),
#  ('Léopold', np.float64(0.06014740223694778)),
#  ('JUIN', np.float64(0.06333775041818981)),
#  ('belges', np.float64(0.0644204487990376)),
#  ('ANNEE', np.float64(0.06465656348242958)),
#  ('JOURNAL', np.float64(0.06506343005919339)),
#  ('Congo constitue', np.float64(0.06770964469415959)),
#  ('fois', np.float64(0.07286761849844757)),
#  ('discours', np.float64(0.07364715822056664)),
#  ('populations', np.float64(0.07384557717115157)),
#  ('grande', np.float64(0.07391368091626649)),
#  ('grand', np.float64(0.0743993158331777)),
#  ('BELGIQUE DONNE', np.float64(0.07581438162541644)),
#  ('Bruxelles vendredi soir', np.float64(0.07595845257308351)),
#  ('d’un', np.float64(0.07606690958792099)),
#  ('Deum', np.float64(0.07972571948340247)),
#  ('HISTORIQUE BELGIQUE', np.float64(0.0818690665412898)),
#  ('République', np.float64(0.08237887658838217)),
#  ('pays', np.float64(0.08735477024365808)),
#  ('CHEQUES POSTAUX PUBltCITE', np.float64(0.08804189271190231)),
#  ('Lumumba suscite Léopoldville', np.float64(0.08869898388624496)),
#  ('noire', np.float64(0.09057039510012542)),
#  ('BRUXELLES', np.float64(0.09083046846140877)),
#  ('Roi Retour', np.float64(0.09168858980866555)),
#  ('Parlement congolais', np.float64(0.09258663669856382))]

# %%
# Ne garder que les bigrammes
kept = []
for kw, score in keywords:
    words = kw.split()
    if len(words) == 2:
        kept.append(kw)
kept
# Out:
# ['JOURNAL OUOTtDlîN',
#  'Congo belge',
#  'roi Léopold',
#  'président Kasavubu',
#  'Roi arrive',
#  'ministres belges',
#  'Patrice Lumumba',
#  'Congo constitue',
#  'BELGIQUE DONNE',
#  'HISTORIQUE BELGIQUE',
#  'Roi Retour',
#  'Parlement congolais']

# %% [markdown]
# ## Faire la même opération sur tous les documents

# %%
for f in sorted(files)[:10]:
    text = open(os.path.join(data_path, f), 'r', encoding="utf-8").read()
    keywords = kw_extractor.extract_keywords(text)
    kept = []
    for kw, score in keywords:
        words = kw.split()
        if len(words) == 2:
            kept.append(kw)
    print(f"{f} mentions these keywords: {', '.join(kept)}...")
# Out:
# KB_JB838_1960-07-01_01-00001.txt mentions these keywords: JOURNAL OUOTtDlîN, Congo belge, roi Léopold, président Kasavubu, Roi arrive, ministres belges, Patrice Lumumba, Congo constitue, BELGIQUE DONNE, HISTORIQUE BELGIQUE, Roi Retour, Parlement congolais...
# KB_JB838_1960-07-01_01-00002.txt mentions these keywords: avons connu, conscience nationale, gouvernement belge, Cour européenne, Congo indépendant, peuple congolais, roi Albert, Pàrlement congolais, Michel Simon...
# KB_JB838_1960-07-01_01-00003.txt mentions these keywords: Roi Léopold, Congo belge, ministres belges, vrai Congo, Etat congolais, pétrole brut, Nations Unies, peuple congolais, d’autre part...
# KB_JB838_1960-07-01_01-00004.txt mentions these keywords: tribunal correctionnel, BISTER Dijon, habitant rue, Dijon exactement, francs d’amende, habitant avenue, Henri Stée, Jeudi matin, moutarde BISTER, d’une voiture, rue Pierre, Jérôme Van, Ferhat Abbas, Vol d’une...
# KB_JB838_1960-07-01_01-00005.txt mentions these keywords: Sam Garmish, qu’il faut, Jean Rombaux, Myron Szolzberg, Miss Gowam, architecte principal, Sandra Coleman, qu’il veut, Vieux Bruxelles, propagande soviétique, Milton Szolzberg, c’est d’un...
# KB_JB838_1960-07-01_01-00006.txt mentions these keywords: NEW YORK, AVIS TIENT, TIENT LIEU, tient Ueu, prie d’annoncer, YORK Cours, conseil communal, MONSIEUR Edouard, juin COURS, faire part, présent avis...
# KB_JB838_1960-07-01_01-00007.txt mentions these keywords: Labour Party, Conseil national, Vienne Vienne, prince Albert, Nations Unies, comité exécutif, Khrouchtchev s’est...
# KB_JB838_1960-07-01_01-00008.txt mentions these keywords: MAMINB HWMI, DOMMIDIA UMANA, Musique légère, MANCA àmanfitm, UMANA lewrpittnllo, tlBNlDB MAMINB, KXXACI teprerldew, Musée communal, FESTIVAL INTERNATIONAL, CONSTANT Musique, IIDOVA Musique, Concert symphonique, musique d'orgue, Brohme Choréographl, Bruxelles MUSIQUE, MASSINI Citer, MneHen artlstiqtM, siècle élaborée, Conseil scolaire, artlstiqtM tlBNlDB, teprerldew IMèretre...
# KB_JB838_1960-07-01_01-00009.txt mentions these keywords: meilleur poulet, FSE Méconnaissance, poulet qu’ils, poulets d’un, d’un poulet, d’une qualité...
# KB_JB838_1960-07-01_01-00010.txt mentions these keywords: Van Aerde, Van Geneugden, Van den, den Borgh, maillot jaune, Marcel Bidot, Jean Adriaenssens...
